# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import folium as fm
sns.set()

# %% [markdown]
# # Load The Data

# %%
df = pd.read_csv(r'C:\Users\nadav\OneDrive\שולחן העבודה\Data Analyst\Python Files\Dubai Apartments\properties_data.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#         id          neighborhood  latitude  longitude    price  size_in_sqft  \
# 0  5528049         Palm Jumeirah 25.113208  55.138932  2700000          1079
# 1  6008529         Palm Jumeirah 25.106809  55.151201  2850000          1582
# 2  6034542  Jumeirah Lake Towers 25.063302  55.137728  1150000          1951
# 3  6326063       Culture Village 25.227295  55.341761  2850000          2020
# 4  6356778         Palm Jumeirah 25.114275  55.139764  1729200           507
#
#    price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  maid_room  \
# 0     2502.320000               1                2  Medium      False
# 1     1801.520000               2                2  Medium      False
# 2      589.440000               3                5  Medium       True
# 3     1410.890000               2                3     Low      False
# 4     3410.650000               0                1  Medium      False
#
#    unfurnished  balcony  barbecue_area  built_in_wardrobes  central_ac  \
# ...

# %% [markdown]
# # Add New Column 'Total Rooms'

# %%
df['Total Rooms'] = df['no_of_bedrooms'] +df['no_of_bathrooms']
df.head()
# Out:
#         id          neighborhood   latitude  longitude    price  size_in_sqft  \
# 0  5528049         Palm Jumeirah  25.113208  55.138932  2700000          1079
# 1  6008529         Palm Jumeirah  25.106809  55.151201  2850000          1582
# 2  6034542  Jumeirah Lake Towers  25.063302  55.137728  1150000          1951
# 3  6326063       Culture Village  25.227295  55.341761  2850000          2020
# 4  6356778         Palm Jumeirah  25.114275  55.139764  1729200           507
#
#    price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  maid_room  \
# 0         2502.32               1                2  Medium      False
# 1         1801.52               2                2  Medium      False
# 2          589.44               3                5  Medium       True
# 3         1410.89               2                3     Low      False
# 4         3410.65               0                1  Medium      False
#
#    unfurnished  balcony  barbecue_area  built_in_wardrobes  central_ac  \
# ...

# %% [markdown]
# # Add New Column 'Price per Room'

# %%
df['Price Per Room']=df['price']/df['Total Rooms']
df.head()
# Out:
#         id          neighborhood   latitude  longitude    price  size_in_sqft  \
# 0  5528049         Palm Jumeirah  25.113208  55.138932  2700000          1079
# 1  6008529         Palm Jumeirah  25.106809  55.151201  2850000          1582
# 2  6034542  Jumeirah Lake Towers  25.063302  55.137728  1150000          1951
# 3  6326063       Culture Village  25.227295  55.341761  2850000          2020
# 4  6356778         Palm Jumeirah  25.114275  55.139764  1729200           507
#
#    price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  maid_room  \
# 0         2502.32               1                2  Medium      False
# 1         1801.52               2                2  Medium      False
# 2          589.44               3                5  Medium       True
# 3         1410.89               2                3     Low      False
# 4         3410.65               0                1  Medium      False
#
#    unfurnished  balcony  barbecue_area  built_in_wardrobes  central_ac  \
# ...

# %%
df['price'].apply(np.ceil)
df.head()
# Out:
#         id          neighborhood   latitude  longitude    price  size_in_sqft  \
# 0  5528049         Palm Jumeirah  25.113208  55.138932  2700000          1079
# 1  6008529         Palm Jumeirah  25.106809  55.151201  2850000          1582
# 2  6034542  Jumeirah Lake Towers  25.063302  55.137728  1150000          1951
# 3  6326063       Culture Village  25.227295  55.341761  2850000          2020
# 4  6356778         Palm Jumeirah  25.114275  55.139764  1729200           507
#
#    price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  maid_room  \
# 0         2502.32               1                2  Medium      False
# 1         1801.52               2                2  Medium      False
# 2          589.44               3                5  Medium       True
# 3         1410.89               2                3     Low      False
# 4         3410.65               0                1  Medium      False
#
#    unfurnished  balcony  barbecue_area  built_in_wardrobes  central_ac  \
# ...

# %%
df.shape
# Out:
# (1905, 40)

# %% [markdown]
# #### 1905 rows and 40 columns .

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### No nulls and No Duplicatas.

# %%
pd.set_option('float_format', '{:f}'.format)
df.describe().T
# Out:
#                       count           mean            std            min  \
# id              1905.000000 7573308.187927  192525.172098 5528049.000000
# latitude        1905.000000      25.116538       0.062647      24.865992
# longitude       1905.000000      55.212338       0.068794      55.069311
# price           1905.000000 2085829.873491 2913199.961504  220000.000000
# size_in_sqft    1905.000000    1417.050394     891.487639     294.000000
# price_per_sqft  1905.000000    1327.243785     668.473559     361.870000
# no_of_bedrooms  1905.000000       1.793176       0.949489       0.000000
# no_of_bathrooms 1905.000000       2.512861       1.063117       1.000000
# Total Rooms     1905.000000       4.306037       1.938197       1.000000
# Price Per Room  1905.000000  455266.003198  365436.753505   91666.666667
#
#                            25%            50%            75%             max
# id              7560167.000000 7631829.000000 7670328.000000  7706643.000000
# ...

# %% [markdown]
# ##### Some intersting information
# - The mean price for apartment is 2,085,829.87 \$
# - The mean rooms in apartment is 4
# - 75 \% of the apartments have 3 rooms
# - The mean price per room is 455,266 \$
# - The mean price for sqtf is 1,327.24 \$

# %% [markdown]
# # Making A Groupby for Neighborhoods

# %%
df_grouped_by= df.groupby(['neighborhood']).mean()
df_grouped_by.head()
# Out:
#                          id  latitude  longitude          price  size_in_sqft  \
# neighborhood
# Al Barari    7601161.000000 25.100127  55.313114 2780739.100000   2594.900000
# Al Barsha    7633653.500000 25.069839  55.245559  647276.000000    633.000000
# Al Furjan    7606737.347826 25.026734  55.148363  791813.869565   1053.086957
# Al Kifaf     7487875.857143 25.233787  55.294217 1694904.428571   1262.714286
# Al Quoz      7705293.000000 25.153080  55.254242  360000.000000    600.000000
#
#               price_per_sqft  no_of_bedrooms  no_of_bathrooms  maid_room  \
# neighborhood
# Al Barari        1086.224000        1.900000         2.700000   0.000000
# Al Barsha        1045.730000        0.750000         1.750000   0.000000
# Al Furjan         783.428261        1.652174         2.391304   0.043478
# Al Kifaf         1379.861429        1.428571         2.142857   0.000000
# Al Quoz           600.000000        0.000000         1.000000   0.000000
#
# ...

# %% [markdown]
# #### Change the neighborhood column index.

# %%
df_grouped_by_2= df.groupby(['neighborhood'],as_index = False).mean().sort_values('price',ascending=False)
df_grouped_by_2.head()
# Out:
#        neighborhood             id  latitude  longitude          price  \
# 46    Palm Jumeirah 7476490.848315 25.113960  55.143523 4379435.005618
# 33         Jumeirah 7576979.589744 25.233951  55.248426 4212666.666667
# 11  Culture Village 7451326.000000 25.226963  55.342499 3677445.272727
# 15   Downtown Dubai 7566110.013245 25.195070  55.274812 2972381.211921
# 10        City Walk 7425135.142857 25.203832  55.262591 2906214.142857
#
#     size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms  maid_room  \
# 46   2084.134831     1758.177303        2.000000         2.758427   0.191011
# 33   1614.487179     2174.387179        1.923077         2.846154   0.102564
# 11   2232.818182     1572.836364        2.181818         3.000000   0.272727
# 15   1498.440397     1807.134934        1.983444         2.745033   0.072848
# 10   1846.357143     1548.307857        2.071429         3.285714   0.000000
#
#     unfurnished  balcony  barbecue_area  built_in_wardrobes  central_ac  \
# ...

# %%
df_grouped_by.shape
# Out:
# (54, 38)

# %% [markdown]
# #### 54 different neighborhoods in the data .

# %%
df1=df_grouped_by.sort_values('price',ascending=False)
df1.head()
# Out:
#                             id  latitude  longitude          price  \
# neighborhood
# Palm Jumeirah   7476490.848315 25.113960  55.143523 4379435.005618
# Jumeirah        7576979.589744 25.233951  55.248426 4212666.666667
# Culture Village 7451326.000000 25.226963  55.342499 3677445.272727
# Downtown Dubai  7566110.013245 25.195070  55.274812 2972381.211921
# City Walk       7425135.142857 25.203832  55.262591 2906214.142857
#
#                  size_in_sqft  price_per_sqft  no_of_bedrooms  \
# neighborhood
# Palm Jumeirah     2084.134831     1758.177303        2.000000
# Jumeirah          1614.487179     2174.387179        1.923077
# Culture Village   2232.818182     1572.836364        2.181818
# Downtown Dubai    1498.440397     1807.134934        1.983444
# City Walk         1846.357143     1548.307857        2.071429
#
#                  no_of_bathrooms  maid_room  unfurnished  balcony  \
# neighborhood
# Palm Jumeirah           2.758427   0.191011     0.550562 0.691011
# ...

# %% [markdown]
# #### The most expensive neighborhood in Dubai is Palm Jumeirah	with  mean price for apartment of 4,379,435 \$ .

# %%
df2=df_grouped_by.sort_values('price',ascending=True)
df2.head()
# Out:
#                                     id  latitude  longitude         price  \
# neighborhood
# Dubai Residence Complex 7700652.000000 25.091311  55.378277 270000.000000
# Al Quoz                 7705293.000000 25.153080  55.254242 360000.000000
# Discovery Gardens       7650620.750000 25.037538  55.145244 414250.000000
# International City      7625044.333333 25.167556  55.405504 416000.000000
# Remraam                 7653160.000000 25.004720  55.250410 444333.000000
#
#                          size_in_sqft  price_per_sqft  no_of_bedrooms  \
# neighborhood
# Dubai Residence Complex    460.000000      586.960000        0.000000
# Al Quoz                    600.000000      600.000000        0.000000
# Discovery Gardens          820.000000      516.437500        0.750000
# International City         752.000000      535.510000        1.000000
# Remraam                    836.833333      563.890000        0.833333
#
# ...

# %% [markdown]
# #### On the other end the most poor neighborhood is Dubai Residence Complex	with the mean price 270,000 \$ .

# %% [markdown]
# # Bar Plot of the Findings

# %%
ax = df1['price'].plot.bar(color='#008B8B',figsize=(20,10))
ax= sns.set_style('whitegrid')
ax= plt.title('Mean Price for Apartment per Neighborhood in Millions',size= 30, fontweight='bold')
ax = plt.xlabel('neighborhood', size = 15)
ax=plt.ylabel('price',size = 15)
ax =sns.despine(left=True)
ax = plt.xticks(rotation=90, size = 16)
ax= plt.yticks(size = 16)

# %% [markdown]
# # Creating a Map

# %%
map = fm.Map(
zoom_start=2
)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df4=df_grouped_by_2.head(10)
df4
# Out:
#                 neighborhood             id  latitude  longitude  \
# 46             Palm Jumeirah 7476490.848315 25.113960  55.143523
# 33                  Jumeirah 7576979.589744 25.233951  55.248426
# 11           Culture Village 7451326.000000 25.226963  55.342499
# 15            Downtown Dubai 7566110.013245 25.195070  55.274812
# 10                 City Walk 7425135.142857 25.203832  55.262591
# 8                 Bluewaters 7608797.500000 25.078699  55.121522
# 52        World Trade Center 7651956.375000 25.226221  55.288902
# 0                  Al Barari 7601161.000000 25.100127  55.313114
# 34  Jumeirah Beach Residence 7595683.456897 25.077493  55.133216
# 17       Dubai Festival City 7641497.200000 25.219387  55.366718
#
#             price  size_in_sqft  price_per_sqft  no_of_bedrooms  \
# 46 4379435.005618   2084.134831     1758.177303        2.000000
# 33 4212666.666667   1614.487179     2174.387179        1.923077
# ...

# %% [markdown]
# #### Inserting the top 10 expensive neighborhoods to the map.

# %%
for row, neighborhood in df4.iterrows():
    fm.Marker(
            location = [neighborhood['latitude'],neighborhood['longitude']],
        tooltip=neighborhood['neighborhood']
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# #### As we can see most of the expensive neighborhood are neared by the sea

# %% [markdown]
# # Heres a link to the notebook with the map :
# https://nbviewer.org/github/Nadavshh/Dubai-Apartments-Analysis/blob/main/Dubai%20Apartments.ipynb

# %% [markdown]
# # More Digging

# %%
plt.figure(figsize=(10,8))
ax= sns.set_style('whitegrid')
ax= plt.title('Count Of Apartments per Total rooms ',size= 20, fontweight='bold')
ax=sns.histplot(data=df, x="Total Rooms",color='#008B8B',binwidth=0.4,kde=True)
ax.lines[0].set_color('black')
ax = plt.xticks(size=14)
ax = plt.yticks(size = 14)
ax = plt.xlabel('Total Rooms',size= 16)
ax = plt.ylabel('Count',size= 16)

# %% [markdown]
# #### We know from before that the average number of total rooms is 4

# %%
plt.figure(figsize=(10,8))
ax= sns.set_style('whitegrid')
ax= plt.title('Count Of Apartments per quality ',size= 20, fontweight='bold')
ax=sns.histplot(data=df, x="quality",color='#008B8B',binwidth=0.4,kde=True)
ax.lines[0].set_color('black')
ax = plt.xticks(size=14)
ax = plt.yticks(size = 14)
ax = plt.xlabel('Quality of Apartment',size= 16)
ax = plt.ylabel('Count',size= 16)

# %% [markdown]
# #### Twice as much medium quality apartments than low quality apartments.

# %%
plt.figure(figsize=(10,8))
ax= sns.set_style('whitegrid')

plt.xticks(size = 14)
plt.yticks(size = 14)
plt.title("Correlation Between Total Rooms and Price",
          size=20,
          fontweight='bold')
plt.xlabel('Total Rooms',size=16)
ax= plt.ylabel(' Price in Millions',size= 16)
ax=sns.regplot(x='Total Rooms',y ='price',data=df,color='#008B8B',ci=None)

# %%
np.corrcoef(df['Total Rooms'],df['price'])
# Out:
# array([[1.       , 0.5273693],
#        [0.5273693, 1.       ]])

# %% [markdown]
# #### The Correlation between the price and the total rooms is preety week(0.53). That's not common in the real estate industry

# %%
plt.figure(figsize=(10,8))
ax= sns.set_style('whitegrid')
ax=sns.regplot(x='size_in_sqft',y ='price',data=df,color='#008B8B',ci=None)
plt.xticks(size = 14)
plt.yticks(size = 14)
#ax.set(xlabel='size_in_sqtf',ylabel='Price')
plt.title("Correlation Between size in sqtf and Price",
          size=20,
          fontweight='bold')
ax=plt.ylabel(' Price in Millions',size= 16)
ax = plt.xlabel('size_in_sqtf',size=16)

# %%
np.corrcoef(df['size_in_sqft'],df['price'])
# Out:
# array([[1.        , 0.80859482],
#        [0.80859482, 1.        ]])

# %% [markdown]
# #### As I was expecting, there is a strong postive correlation(0.81) between the size of the apartment and the price

# %% [markdown]
# # Let's Create an Heatmap to see wide information about the correlations

# %%
plt.subplots(figsize=(15, 12))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot = False,cmap="YlGnBu")
plt.show()

# %% [markdown]
# ### From the heatmap we can conclude that the main variable that has  high correlation with the price  is the size of the apartment. The size in sqtf is the main factor to the apartment price.

# %%
np.corrcoef(df['lobby_in_building'],df['childrens_pool'])
# Out:
# array([[1.        , 0.81708786],
#        [0.81708786, 1.        ]])

# %% [markdown]
# #### Correlation of 0.82 between lobby in the bulding and childerns pool (?)
# #### We can assume that if there is a pool it's in the lobby.

# %%
np.corrcoef(df['lobby_in_building'],df['childrens_pool'])

# %%
plt.figure(figsize=(10,8))
ax= sns.set_style('whitegrid')
ax=sns.boxplot(x=df["no_of_bedrooms"], y=df["no_of_bathrooms"],color='#008B8B',showmeans=True,)
ax=plt.title("Number of Bedroom and Number of Bathrooms",
          size=20,
          fontweight='bold')
ax=plt.xticks(size = 14)
ax=plt.yticks(size = 14)
ax = plt.xlabel('Number of Bedrooms',size=16)
ax = plt.ylabel('Number of Bathrooms',size=16)

# %% [markdown]
# #### Here is some intersting inforamtion from the boxplot:
# - Rooms with 0 bedrooms have obviously only 1 bathrooms.
# - 75% from the apartments with 1 bedroom have between 1-2 bathrooms.
# - The top 25% of the apartments with 2 bed rooms have 3-4 bathrooms.
# - Apartments with 4 bedrooms have minimum 3 bathrooms and there are apartments with even 6 bathrooms and the average bathrooms bumber is between 4-5.
